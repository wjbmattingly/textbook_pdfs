# %%
# !pip install pypdf2
# Out:
# WARNING: You are using pip version 21.1.2; however, version 21.1.3 is available.
# You should consider upgrading via the 'c:\users\wma22\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# ...

# %%
from PyPDF2 import PdfFileMerger

# %%
import glob

# %%
files = glob.glob("data/*.pdf")

# %%
print (files)
# Out:
# ['data\\16274182738888bsb00000539.pdf', 'data\\16274183078888bsb00000539.pdf', 'data\\16274183258888bsb00000539.pdf']

# %%
merger = PdfFileMerger()

# %%
for file
